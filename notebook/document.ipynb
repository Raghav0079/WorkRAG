# %% [markdown]
# ### Data Ingestion

# %%
from langchain_core.documents import Document

# %%
doc=Document(
    page_content="this is the main text content I am using to create RAG",
    metadata={
        "source":"exmaple.txt",
        "pages":1,
        "author":"Krish Naik",
        "date_created":"2025-01-01"
    }
)
doc
# Out:
# Document(metadata={'source': 'exmaple.txt', 'pages': 1, 'author': 'Krish Naik', 'date_created': '2025-01-01'}, page_content='this is the main text content I am using to create RAG')

# %%
import os
os.makedirs("../data/text_files",exist_ok=True)

# %%
sample_texts={
    "../data/text_files/python_intro.txt":"""Python Programming Introduction

Python is a high-level, interpreted programming language known for its simplicity and readability.
Created by Guido van Rossum and first released in 1991, Python has become one of the most popular
programming languages in the world.

Key Features:
- Easy to learn and use
- Extensive standard library
- Cross-platform compatibility
- Strong community support

Python is widely used in web development, data science, artificial intelligence, and automation.""",
    
    "../data/text_files/machine_learning.txt": """Machine Learning Basics

Machine learning is a subset of artificial intelligence that enables systems to learn and improve
from experience without being explicitly programmed. It focuses on developing computer programs
that can access data and use it to learn for themselves.

Types of Machine Learning:
1. Supervised Learning: Learning with labeled data
2. Unsupervised Learning: Finding patterns in unlabeled data
3. Reinforcement Learning: Learning through rewards and penalties

Applications include image recognition, speech processing, and recommendation systems
    
    
    """

}

for filepath,content in sample_texts.items():
    with open(filepath,'w',encoding="utf-8") as f:
        f.write(content)

print("✅ Sample text files created!")
# Out:
# ✅ Sample text files created!

# %%
### TextLoader

from langchain_community.document_loaders import TextLoader

loader=TextLoader("../data/text_files/python_intro.txt",encoding="utf-8")
document=loader.load()
print(document)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
### Directory Loader
from langchain_community.document_loaders import DirectoryLoader

## load all the text files from the directory
dir_loader=DirectoryLoader(
    "../data/text_files",
    glob="**/*.txt", ## Pattern to match files  
    loader_cls= TextLoader, ##loader class to use
    loader_kwargs={'encoding': 'utf-8'},
    show_progress=False

)

documents=dir_loader.load()
documents
# Out:
# [Document(metadata={'source': '..\\data\\text_files\\machine_learning.txt'}, page_content='Machine Learning Basics\n\nMachine learning is a subset of artificial intelligence that enables systems to learn and improve\nfrom experience without being explicitly programmed. It focuses on developing computer programs\nthat can access data and use it to learn for themselves.\n\nTypes of Machine Learning:\n1. Supervised Learning: Learning with labeled data\n2. Unsupervised Learning: Finding patterns in unlabeled data\n3. Reinforcement Learning: Learning through rewards and penalties\n\nApplications include image recognition, speech processing, and recommendation systems\n\n\n    '),
#  Document(metadata={'source': '..\\data\\text_files\\python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader

## load all the text files from the directory
dir_loader=DirectoryLoader(
    "../data/pdf",
    glob="**/*.pdf", ## Pattern to match files  
    loader_cls= PyMuPDFLoader, ##loader class to use
    show_progress=False

)

pdf_documents=dir_loader.load()
pdf_documents
# Out:
# [Document(metadata={'producer': 'Microsoft: Print To PDF', 'creator': '', 'creationdate': '2024-03-11T15:34:28+05:30', 'source': '..\\data\\pdf\\2024 answer key.pdf', 'file_path': '..\\data\\pdf\\2024 answer key.pdf', 'total_pages': 2, 'format': 'PDF 1.7', 'title': 'DAKeys.xlsx', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-03-11T15:34:28+05:30', 'trapped': '', 'modDate': "D:20240311153428+05'30'", 'creationDate': "D:20240311153428+05'30'", 'page': 0}, page_content='Q. No.\nSession\nQuestion \nType \nSection\nKey/Range \nMark \n1\n1\nMCQ\nGA\nD\n1\n2\n1\nMCQ\nGA\nA\n1\n3\n1\nMCQ\nGA\nB\n1\n4\n1\nMCQ\nGA\nB\n1\n5\n1\nMCQ\nGA\nB\n1\n6\n1\nMCQ\nGA\nD\n2\n7\n1\nMCQ\nGA\nA\n2\n8\n1\nMCQ\nGA\nB\n2\n9\n1\nMCQ\nGA\nA\n2\n10\n1\nMCQ\nGA\nA\n2\n11\n1\nMCQ\nDA\nA\n1\n12\n1\nMCQ\nDA\nA\n1\n13\n1\nMCQ\nDA\nB\n1\n14\n1\nMCQ\nDA\nA\n1\n15\n1\nMCQ\nDA\nA\n1\n16\n1\nMCQ\nDA\nA\n1\n17\n1\nMCQ\nDA\nD\n1\n18\n1\nMCQ\nDA\nC\n1\n19\n1\nMCQ\nDA\nD\n1\n20\n1\nMCQ\nDA\nB\n1\n21\n1\nMCQ\nDA\nB\n1\n22\n1\nMCQ\nDA\nA\n1\n23\n1\nMCQ\nDA\nD\n1\n24\n1\nMCQ\nDA\nC\n1\n25\n1\nMCQ\nDA\nC\n1\n26\n1\nMCQ\nDA\nC\n1\n27\n1\nMCQ\nDA\nB\n1\n28\n1\nMSQ\nDA\nA;B;C\n1\n29\n1\nMSQ\nDA\nB;C;D\n1\nData Science & Artificial Intelligence (DA) \nFinal Answer Key\nPage 1 of 2'),
#  Document(metadata={'producer': 'Microsoft: Print To PDF', 'creator': '', 'creationdate': '2024-03-11T15:34:28+05:30', 'source': '..\\data\\pdf\\2024 answer key.pdf', 'file_path': '..\\data\\pdf\\2024 answer key.pdf', 'total_pages': 2, 'format': 'PDF 1.7', 'title': 'DAKeys.xlsx', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2024-03-11T15:34:28+05:30', 'trapped': '', 'modDate': "D:20240311153428+05'30'", 'creationDate': "D:20240311153428+05'30'", 'page': 1}, page_content='30\n1\nNAT\nDA\n0 to 0\n1\n31\n1\nNAT\nDA\n3 to 3\n1\n32\n1\nNAT\nDA\n17 to 17\n1\n33\n1\nNAT\nDA\n0.24 to 0.24\n1\n34\n1\nNAT\nDA\n42 to 42\n1\n35\n1\nNAT\nDA\n0 to 0\n1\n36\n1\nMCQ\nDA\nC\n2\n37\n1\nMCQ\nDA\nA\n2\n38\n1\nMCQ\nDA\nD\n2\n39\n1\nMCQ\nDA\nC\n2\n40\n1\nMCQ\nDA\nA\n2\n41\n1\nMCQ\nDA\nC\n2\n42\n1\nMCQ\nDA\nA\n2\n43\n1\nMCQ\nDA\nA\n2\n44\n1\nMCQ\nDA\nC\n2\n45\n1\nMCQ\nDA\nB\n2\n46\n1\nMSQ\nDA\nA;B;D\n2\n47\n1\nMSQ\nDA\nA;C\n2\n48\n1\nMSQ\nDA\nB;D\n2\n49\n1\nMSQ\nDA\nB;C;D\n2\n50\n1\nMSQ\nDA\nA;B\n2\n51\n1\nMSQ\nDA\nB;D\n2\n52\n1\nMSQ\nDA\nA;B;C\n2\n53\n1\nMSQ\nDA\nA;D\n2\n54\n1\nMSQ\nDA\nA;C\n2\n55\n1\nMSQ\nDA\nA;B\n2\n56\n1\nNAT\nDA\n0.125 to 0.125\n2\n57\n1\nNAT\nDA\n0.2 to 0.2\n2\n58\n1\nNAT\nDA\n0.25 to 0.25\n2\n59\n1\nNAT\nDA\nMTA\n2\n60\n1\nNAT\nDA\n0.5 to 0.5\n2\n61\n1\nNAT\nDA\n55 to 55\n2\n62\n1\nNAT\nDA\n0.12 to 0.13\n2\n63\n1\nNAT\nDA\n5 to 5\n2\n64\n1\nNAT\nDA\n0.125 to 0.125\n2\n65\n1\nNAT\nDA\n0.062 to 0.063\n2\nPage 2 of 2'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2024-02-03T23:13:08+05:30', 'source': '..\\data\\pdf\\2024 paper memory based.pdf', 'file_path': '..\\data\\pdf\\2024 paper memory based.pdf', 'total_pages': 17, 'format': 'PDF 1.7', 'title': '', 'author': 'PW MSO 256', 'subject': '', 'keywords': '', 'moddate': '2024-02-03T23:14:34+05:30', 'trapped': '', 'modDate': "D:20240203231434+05'30'", 'creationDate': "D:20240203231308+05'30'", 'page': 0}, page_content='DATA SCIENCE AND\nARTIFICIAL INTELLIGENCE\nDETAILED SOLUTION BY TEAM\nEXAM HELD ON\nrd\n3  FEBRUARY 2024\nMORNING SESSION\nDATA SCIENCE AND\nARTIFICIAL INTELLIGENCE\nFOLLOW US:\nMOBILE APP\nYOUTUBE\nTWITTER\nFACEBOOK\nTELEGRAM'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2024-02-03T23:13:08+05:30', 'source': '..\\data\\pdf\\2024 paper memory based.pdf', 'file_path': '..\\data\\pdf\\2024 paper memory based.pdf', 'total_pages': 17, 'format': 'PDF 1.7', 'title': '', 'author': 'PW MSO 256', 'subject': '', 'keywords': '', 'moddate': '2024-02-03T23:14:34+05:30', 'trapped': '', 'modDate': "D:20240203231434+05'30'", 'creationDate': "D:20240203231308+05'30'", 'page': 1}, page_content="PAGE \n1 \n \n             \n \nPW Mobile APP: https://smart.link/7wwosivoicgd4   \n  https://t.me/Gwcomsciandinfo \n                https://www.youtube.com/@GATEWallah_EE_EC_CS \n https://www.youtube.com/@GATEWallahbyPW \nDATA SCIENCE  & ARTIFICIAL INTELLIGENCE \n[MCQ]  \nQ.1. \n“Which algorithm sort the array in exactly using 2 swap [4, 3, 2, 1, 5] \n \nSelection sort \n \nInsertion sort \n \nBubble sort” \n \n(a) \nSelection sort \n(b) \nInsertion sort \n \n(c) \nBuffel sort  \n(d) \nNone of these \nSol. \n(a) \n \n4\n3\n2 1\n5\n1\n3\n2\n4 5\nend of pass 1\n1\n2\n3\n4 5\nend of pass 2\n\uf0ac\n\uf0ad\n\uf0ac\n \n \n\uf05c  ‘a’ is correct answer. \n \n[NAT] \nQ.2. \nHow many 4 digit number can be formed using digits 1, 3, 4, 6, 7 divisible by 3.  \nSol. \nOn deleting 3 from digits the remaining digits would sum up to 18 which is multiple of \n3. So the 4 digit number can be formed using digit 1, 4, 6, 7 are 24.  \n \nOn deleting 6 from digits the remaining digits would sum up to 15 which is multiple of \n3. So the 4 digit number can be formed using digit 1, 3, 4, 7 are 24. \n \nTherefore, total 4 digits no. will be 24 + 24 = 48.  \n[NAT] \nQ.3. \nLet \n(\n)\n2\n2\nx\n0\nln (x\n1)cosx\nLim\nx\n→\n+\n \nSol. \n(1/2) \n \n(\n)\n2\n2\n0\n1 cos\nlim\nx\nln\nx\nx\nx\n→\n\uf0e9\n\uf0f9\n+\n\uf0eb\n\uf0fb \n \nPutting x → 0 in the above part we get \n \n( )\n\uf07b\n\uf07d\n1\ncos\n0\n0\n0\nln\nx\nfrom\n\uf0b4\n=\n \n \nThus, using L-hospital Rule there \n \n \n( )\n( )\n( )\n( )\n'\nlim\nlim\n'\nx\na\nx\na\nf n\nf\nn\ng n\ng n\n→\n→\n=\n \n \nSo, differentiating it we get- \n \n(\n)\n(\n)\n2\n2\n1\ncos\n2\n1\nsin\n1 .cos\n2\nx\nx\nx\nx\nx\nx\nx\n\uf0e9\n\uf0f9\n\uf0d7\n+\n+\n−\n\uf0eb\n\uf0fb\n+\n\uf0de"),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2024-02-03T23:13:08+05:30', 'source': '..\\data\\pdf\\2024 paper memory based.pdf', 'file_path': '..\\data\\pdf\\2024 paper memory based.pdf', 'total_pages': 17, 'format': 'PDF 1.7', 'title': '', 'author': 'PW MSO 256', 'subject': '', 'keywords': '', 'moddate': '2024-02-03T23:14:34+05:30', 'trapped': '', 'modDate': "D:20240203231434+05'30'", 'creationDate': "D:20240203231308+05'30'", 'page': 2}, page_content='PAGE \n2 \n \n             \n \nPW Mobile APP: https://smart.link/7wwosivoicgd4   \n  https://t.me/Gwcomsciandinfo \n                https://www.youtube.com/@GATEWallah_EE_EC_CS \n https://www.youtube.com/@GATEWallahbyPW \nDATA SCIENCE  & ARTIFICIAL INTELLIGENCE \n \n2\n2\nsin\ncos\n1\n2\nx\nx\nx\nx\nx\n−\n+\n\uf0de\n \n \n2\n1\nsin\n2\ncos\n1\n\uf0de\n−\n\uf0d7\n+\nx\nx\nx\nx\n \n \nThus, \n(\n)\n\uf07b\n\uf07d\n2\n2\n0\n1 cos\nlim\nx\nln\nx\nx\nx\n→\n+\n= \n2\n0\n1\nsin\nlim\n2 cos\n1\nx\nx\nx\nx\n→\n\uf0ec\n\uf0fc\n−\n\uf0ed\n\uf0fd\n+\n\uf0ee\n\uf0fe\n \n \n0\n1\nsin\n1\n1\nlim\n2\ncos\n→\n−\n\uf0b4\nx\nx\nx\nx  \n \n1\n1\n1 1\n2\n−\n\uf0b4\uf0b4 \n \n1\n1\n1\n2\n2\n−\n=\n \n[NAT] \nQ.4. \nA dice is thrown repeatedly. Expected number of throws required until two consecutive \nthrows shows even number _____. \nSol. \n(6) \n \nPI = ½  \n \n2\n1\n1\n1\n1\nN\n6\np\np\n1/ 2\n1/ 4\n=\n+\n=\n+\n=\n  \n \n[NAT] \nQ.5. \n1\n2\n3\nM= 3\n1\n3\n4\n3\n6\n\uf0e9\n\uf0f9\n\uf0ea\n\uf0fa\n\uf0ea\n\uf0fa\n\uf0ea\n\uf0fa\n\uf0eb\n\uf0fb\ndet [M2 + 12M]               . \nSol. \n(0) \n \n= det [M2 + 12M] \n \n| M2 + 12M| \n \n|M(M+ 12I|)| \n \n|M|  |M+ 12I| \n \nNow,  |M| = 1\n3\n1 3\n6  \n3\n3\n2 4\n6\n−\n \n3\n1\n3 4\n3\n+\n \n \n = 1 (6 – 9) – 2 (18 – 12) + 3 (9 – 4) \n \n= – 3 – 12 + 15 \n \n= – 15 + 15 = 0 \n \nDet [M2 + 12M] \n \n|M|  |M+ 12I| = 0 × (|M + 12I| = 0)'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2024-02-03T23:13:08+05:30', 'source': '..\\data\\pdf\\2024 paper memory based.pdf', 'file_path': '..\\data\\pdf\\2024 paper memory based.pdf', 'total_pages': 17, 'format': 'PDF 1.7', 'title': '', 'author': 'PW MSO 256', 'subject': '', 'keywords': '', 'moddate': '2024-02-03T23:14:34+05:30', 'trapped': '', 'modDate': "D:20240203231434+05'30'", 'creationDate': "D:20240203231308+05'30'", 'page': 3}, page_content='PAGE \n3 \n \n             \n \nPW Mobile APP: https://smart.link/7wwosivoicgd4   \n  https://t.me/Gwcomsciandinfo \n                https://www.youtube.com/@GATEWallah_EE_EC_CS \n https://www.youtube.com/@GATEWallahbyPW \nDATA SCIENCE  & ARTIFICIAL INTELLIGENCE \n[NAT] \nQ.6. \nData set with k -binary value attribute (where k>2) for a two class classification task \nthe number of parameters to be estimated for learning a view … b…. ……. \n \n(a) \n2k + 1 \n(b) \n k2 +1 \n \n(c)  \n2k+1+1  \n(d) \n 2k+1    \nSol. \n(b) \n \nThe total number of parameter is 3k + 2 & when you subsituted 3k + 2  for k2 + 1. \n \n[MSQ] \nQ.7. \nConsider the DAG below: \n \n \nWhich of the following is/are valid vertex ordering that can be obtained from \ntopological sort of the DAG? \n \n(a) \nPRQVSUT \n(b) \nPQRSVUT \n \n(c) \nPQRSTUV \n(d) \nPRQSVTU \nSol. \n(a, d) \n \nSol.(1). G = (V,E) directed \n \n(1) \nVisit vertex with in-degree ‘0’ \n \n(2) \nDelete that vertex from the graph and repeat step-1 until graph becomes empty. \n \n \n \nSol.(2). By observing graph we can say that, Q cannot be selected as there are incoming \nedge, so the option c and b are eliminated. \n \nIf we select R, there is only one node to be selected that is Q, after selecting Q the \nremaining nodes. Left deleted us. Hence, we are left with the modes (S, U) and (V, T), \nany of these modes can be selected and deleted in any order. \n \n\uf05c   Correct option are ‘a’ and ‘d’.   \nP \nQ \nS \nU \nV \nT \nR'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2024-02-03T23:13:08+05:30', 'source': '..\\data\\pdf\\2024 paper memory based.pdf', 'file_path': '..\\data\\pdf\\2024 paper memory based.pdf', 'total_pages': 17, 'format': 'PDF 1.7', 'title': '', 'author': 'PW MSO 256', 'subject': '', 'keywords': '', 'moddate': '2024-02-03T23:14:34+05:30', 'trapped': '', 'modDate': "D:20240203231434+05'30'", 'creationDate': "D:20240203231308+05'30'", 'page': 4}, page_content='PAGE \n4 \n \n             \n \nPW Mobile APP: https://smart.link/7wwosivoicgd4   \n  https://t.me/Gwcomsciandinfo \n                https://www.youtube.com/@GATEWallah_EE_EC_CS \n https://www.youtube.com/@GATEWallahbyPW \nDATA SCIENCE  & ARTIFICIAL INTELLIGENCE \n[MCQ] \nQ.8. \nConsider the function computes (X) whose pseudo code is given below: \n \nWhich one of the following \n \nValues is returned by the computes (X) for X= [6, 3, 5, 4, 10] \n \ncomputes (X) \n \nS[1] \uf0ac 1 \n \nfor i \uf0ac 2 to length (X) \n \nS[i] \uf0ac 1 \n \n \nif X[i – 1] \uf0a3 X[i] \n \n \nS[i] \uf0ac S[i] + S [i –1] \n \nend if \n \nend for \n \nreturn S \n \n(a) \n[1, 1, 2, 3, 3] \n(b) \n[1, 1, 2, 3, 4] \n \n(c) \n[1, 1, 2, 1, 2] \n(d) \n[1, 1, 2, 1, 5] \nSol. \n(c) \n \nFor i = 2 \n \nS[2] \uf0ac 1 \n \nIf 6 < 3 // condition false \n \nFor i = 3 \n \nS[3] \uf0ac 1 \n \nIf 3 < 5 // condition true \n \nS[3] \uf0ac S[3] + S [2] = S[3] \uf0ac 1 + 1 = 2 \n \nTherefore, S[1] = 1, S[2] = 1, S[3] = 2, S[4] = 1, S[5] = 2. \n \nHence, the option (c) is correct. \n \n[MSQ] \nQ.9. \nGiven the relational schema R = (U, V, W, X, Y, Z) and the set of functional \ndependencies: \n \nU\nV\nU\nW\nF\nWX\nY\nWX\nZ\nV\nX\n→\n\uf0ec\n\uf0fc\n\uf0ef\n\uf0ef\n→\n\uf0ef\n\uf0ef\n\uf0ef\n\uf0ef\n=\n→\n\uf0ed\n\uf0fd\n\uf0ef\n\uf0ef\n→\n\uf0ef\n\uf0ef\n→\n\uf0ef\n\uf0ef\n\uf0ee\n\uf0fe\n \n \nWhich of the following FD can be derived from the above set? \n \n(a) \nVW\uf0ae Y \n(b) \nVW \uf0ae YZ \n \n(c) \nVW\uf0ae U \n(d) \nWX \uf0ae YZ \nSol. \n(a, b, d) \n \nGiven R = (U, V, W, X, Y, Z) \n \nFD set: {U\uf0aeV, U\uf0aeW, WX\uf0aeY, WX\uf0aeZ, V\uf0aeX}'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2024-02-03T23:13:08+05:30', 'source': '..\\data\\pdf\\2024 paper memory based.pdf', 'file_path': '..\\data\\pdf\\2024 paper memory based.pdf', 'total_pages': 17, 'format': 'PDF 1.7', 'title': '', 'author': 'PW MSO 256', 'subject': '', 'keywords': '', 'moddate': '2024-02-03T23:14:34+05:30', 'trapped': '', 'modDate': "D:20240203231434+05'30'", 'creationDate': "D:20240203231308+05'30'", 'page': 5}, page_content='PAGE \n5 \n \n             \n \nPW Mobile APP: https://smart.link/7wwosivoicgd4   \n  https://t.me/Gwcomsciandinfo \n                https://www.youtube.com/@GATEWallah_EE_EC_CS \n https://www.youtube.com/@GATEWallahbyPW \nDATA SCIENCE  & ARTIFICIAL INTELLIGENCE \n \n[VW]+ = {V, X, W, Y, Z} \n \nTherefore VW\uf0aeY true, also VW\uf0aeYZ also true and VW\uf0aeU is false \n \n[WX]+ = {W, X, Z, Y} \n \nTherefore WX \uf0ae YZ true. \n \nOption a, b and d are correct.  \n \n[MCQ] \nQ.10. Let f (n) denotes the maximum number of comparison made while searching for an \nentry in a sorted array of size n using binary search. \n \nWhich one of the following options is TRUE? \n \n(a) \n( )\n(\n)\n/ 2\nF n\nF\nn\n=\n\uf0ea\n\uf0fa\n\uf0eb\n\uf0fb \n(b) \n( )\n(\n)\n(\n)\n/ 2\n/ 2\nF n\nF\nn\nF\nn\n=\n+\n\uf0ea\n\uf0fa\n\uf0ea\n\uf0fa\n\uf0eb\n\uf0fb\n\uf0eb\n\uf0fb\n \n \n(c) \n( )\n(\n)1\n1\nF n\nF n\n=\n−\n+  \n(d) \n( )\n(\n)\n/ 2\n1\nF n\nF\nn\n=\n+\n\uf0ea\n\uf0fa\n\uf0eb\n\uf0fb\n \nSol. \n(d) \n \nIn bianry search in one comparision entire array is divided into two halves. If we have \ninput array size of n, then in one comparison we are making the size to n/2.  \n \nSo,  \n( )\n(\n)\n/ 2\n1\nF n\nF\nn\n=\n+\n\uf0ea\n\uf0fa\n\uf0eb\n\uf0fb\n \n \nHence, option (d) is correct. \n \n \n[NAT] \nQ.11. Dataset with data point (\n)(\n)\n(\n)\n\uf07b\n\uf07d\n1 1\n2 2\n6 6\nx y\nx y\n..... x y\n  \n \n1\n2\n3\n4\n5\n6\n1\n6\n0\n–1\n2\n–2\nx\n,x\n,x\n,x\n,x\n,x\n0\n1\n–1\n0\n2\n–2\n\uf0e9\uf0f9\n\uf0e9\uf0f9\n\uf0e9\n\uf0f9\n\uf0e9\n\uf0f9\n\uf0e9\uf0f9\n\uf0e9\n\uf0f9\n=\n=\n=\n=\n=\n=\n\uf0ea\uf0fa\n\uf0ea\uf0fa\n\uf0ea\n\uf0fa\n\uf0ea\n\uf0fa\n\uf0ea\uf0fa\n\uf0ea\n\uf0fa\n\uf0eb\uf0fb\n\uf0eb\uf0fb\n\uf0eb\n\uf0fb\n\uf0eb\n\uf0fb\n\uf0eb\uf0fb\n\uf0eb\n\uf0fb\n labels y1 = y2 = y5 = 1, \ny3 = y4 = y6 = –1.  \n \nA hard margin linear support vertex machine is trained on the above data set support \nvector.? \n \nx4 x3 | x3 x4 x5 | x1 x2 x3 x4 | x1 x2 x5 joint probabilities. \n \nEg: (\n) (\n) \uf07b\nx,y\nf\nx, y  0, 2xy  0 < x < 2  0 < y < x   \n \n\uf05b\n\uf05d\nE y| x 1.5\n=\n is \nSol. \n(6) \n \nThe support vectors for the hard margin linear SVM trained on the given dataset are: \n \n[[0. –1. ]] \n \n[[–1. 0.]] \n \n[[1. 0.]] \n \n2. Joint Probabilities \n \nThe joint probabilities for the specified combinations of data points are: \n \nX4 X3 0.333333'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2024-02-03T23:13:08+05:30', 'source': '..\\data\\pdf\\2024 paper memory based.pdf', 'file_path': '..\\data\\pdf\\2024 paper memory based.pdf', 'total_pages': 17, 'format': 'PDF 1.7', 'title': '', 'author': 'PW MSO 256', 'subject': '', 'keywords': '', 'moddate': '2024-02-03T23:14:34+05:30', 'trapped': '', 'modDate': "D:20240203231434+05'30'", 'creationDate': "D:20240203231308+05'30'", 'page': 6}, page_content="PAGE \n6 \n \n             \n \nPW Mobile APP: https://smart.link/7wwosivoicgd4   \n  https://t.me/Gwcomsciandinfo \n                https://www.youtube.com/@GATEWallah_EE_EC_CS \n https://www.youtube.com/@GATEWallahbyPW \nDATA SCIENCE  & ARTIFICIAL INTELLIGENCE \n \nX3 X4 X5: 0.166667 \n \nX1 X2 X3 X4: 0.166667 \n \nX1 X2 X5: 0.333333 \n \n3. E[y | x = 1.5]: \n \nThe conditional expectation E[y |x = 1.5] is calculated to be –-1.5 \n \nExplanation: The support vectors represent the data points that lie closest to the \ndecision boundary of the SVM They are crucial for defining the margin and the \norientation of the separating hyperplane Joint probabilities describe the likelihood of \ntwo events occurring together. In this case: they indicate the probability of specific \ncombinations of data points. \n \nE[y | x = 1.5] represents the expected value of y given that x = 1.5. It's a conditional \nexpectation that measures the average value of y we expect to observe when x takes \nthe value of 1.5. \n \n[MSQ] \nQ.12. Consider performing DFS on an undirected unweighted graph G, starting at vertex S. \nFor any vertex U in G, d[U] is the length of the shortest path from S to U. Let (U, V) \nbe an edge in G, Such that d(V) < d(V) . If the edge (U, V) is explored first in the \ndirection from U to V, during the above DFS, then (U, V) becomes _____ edge. \n \n(a) \nBack  \n(b) \nGray \n \n(c) \nCross  \n(d) \nTree \nSol. \n(d) \n \n \n \nTaking possible DFS starting from ‘S’. \n \nA \uf0ae B \uf0ae C \uf0ae D \uf0ae F \uf0ae E \n \n \n \nFrom above illustration, edges C, D are past of the tree. \n \nTherefore, Option (d) is correct. \n \n \n \n \nB\nA\nC\nD\nE\nF\nd(B) = 1\nd(D) = 2\nd(F) = 3\nd(E) = 3\nd(C) = 1\nd(A) = 0\nU\nU\nV\nStart"),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2024-02-03T23:13:08+05:30', 'source': '..\\data\\pdf\\2024 paper memory based.pdf', 'file_path': '..\\data\\pdf\\2024 paper memory based.pdf', 'total_pages': 17, 'format': 'PDF 1.7', 'title': '', 'author': 'PW MSO 256', 'subject': '', 'keywords': '', 'moddate': '2024-02-03T23:14:34+05:30', 'trapped': '', 'modDate': "D:20240203231434+05'30'", 'creationDate': "D:20240203231308+05'30'", 'page': 7}, page_content="PAGE \n7 \n \n             \n \nPW Mobile APP: https://smart.link/7wwosivoicgd4   \n  https://t.me/Gwcomsciandinfo \n                https://www.youtube.com/@GATEWallah_EE_EC_CS \n https://www.youtube.com/@GATEWallahbyPW \nDATA SCIENCE  & ARTIFICIAL INTELLIGENCE \n[MCQ] \nQ.13. Match the items in column 1 with the item in column 2 in the following table. \nColumn 1 \nColumn 2 \n(p) \nFirst In First out \n(i) \nStacks \n(q) \nLookup Operation \n(ii) \nQueues \n(r) \nLast in First out \n(iii) \nHash table \n \n(a) \np-(i), q-(ii), r-(iii) \n(b) \np-(iii), q-(ii), r-(i) \n \n(c) \np-(ii), q-(iii), r-(i) \n(d) \np-(iii), q-(i), r-(ii) \nSol. \n(c) \n(i) \nStacks : Stacks follow last in first out. \n(ii) \nQueues : Queues follow first in first out \n(iii) Hash table : Lookup Operation performed on hash table. \n \n[MSQ] \nQ.14. Consider the following tree traversal on FBT  \n \n(i) \nPre order \n \n \n(ii) \nIn order \n \n \n(iii) Post order \nWhich of the following traversal options is/are sufficient to uniquely reconstruct the \nFBT? \n \n(a) \n(i) and (ii) only \n(b) \n(ii) and (iii) only \n \n(c) \n(iii) and (i) only \n(d) \n(i) only \nSol. \n(a, b) \n \nFull binary tree can be constructed uniquely with given data. \n(i) \nIn order and Pre order \n(ii) \nIn order and post order \n \n[NAT] \nQ.15. Consider sorting the following array of integer in ascending order using an inplace \nQuick sort that uses last element as the pivot table \n60 \n70 \n80 \n90 \n100 \n \nThe minimum number of swaps performed during the Quick sort? \nSol. \n(0) \n \nGiven array,  60, 70, 80, 90, 100. During the partitioning step, all elements are \ncompared with the pivot (which is 100 in this case). Since all other elements are smaller \nthan 100, there won't be any swaps in the partitioning step. Thus, the minimum number \nof swaps performed during the Quick Sort is 0."),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2024-02-03T23:13:08+05:30', 'source': '..\\data\\pdf\\2024 paper memory based.pdf', 'file_path': '..\\data\\pdf\\2024 paper memory based.pdf', 'total_pages': 17, 'format': 'PDF 1.7', 'title': '', 'author': 'PW MSO 256', 'subject': '', 'keywords': '', 'moddate': '2024-02-03T23:14:34+05:30', 'trapped': '', 'modDate': "D:20240203231434+05'30'", 'creationDate': "D:20240203231308+05'30'", 'page': 8}, page_content="PAGE \n8 \n \n             \n \nPW Mobile APP: https://smart.link/7wwosivoicgd4   \n  https://t.me/Gwcomsciandinfo \n                https://www.youtube.com/@GATEWallah_EE_EC_CS \n https://www.youtube.com/@GATEWallahbyPW \nDATA SCIENCE  & ARTIFICIAL INTELLIGENCE \n[NAT] \nQ.16. Let f : R→R be the function f(x) = \n1\n1\nx\ne−\n+\n. The value of the derivative of at  x where \nf(x) = 0.4 is. \nSol. \n(0.24) \n \nf(x) = 0.4 \n \n1\n0.4\n1\nx\ne−=\n+\n \n \n1\n1\n0.4\nx\ne−\n+\n=\n \n \n1\n1\n0.4\nx\ne−=\n−\n1\n0.4\n0.4\n−\n=\n \n \n0.6\n0.4\nx\ne−=\n \n \n6\n3\n4\n2\nx\ne−=\n=\n \n \n1\n3\n2\nx\ne\n=\n \n \n2\n3\nx\ne =\n \n \n2\n \n3\nx\nln e\nln\n=\n \n \n2\n3\nx\nln\n=\n \n \n( )\n1\n'\n1\nx\nd\nf\nx\ndx\ne−\n\uf0e6\n\uf0f6\n=\n\uf0e7\n\uf0f7\n+\n\uf0e8\n\uf0f8\n \n \n            \n(\n)\n(\n)\n2\n1\n1\n1\nx\nx\ne\ne\n−\n−\n−\n=\n\uf0b4\n\uf0b4−\n+\n \n(\n)\n2\n1\nx\nx\ne\ne\n−\n−\n=\n+\n \n \nNow, \n2\n3\nx\nln\n=\n \n \n  \n3\nln\nx\ne\ne\n\uf032\n−\n−=\n \n \n         \n3\nln\ne\n\uf032\n=\n  \n3\n2\n=\n \n \n           \n2\n3\n2\n2\n'\n3\n3\n1\n2\nf\nln\n\uf0e6\n\uf0f6\n=\n=\n\uf0e7\n\uf0f7\n\uf0e8\n\uf0f8\n\uf0e6\n\uf0f6\n\uf0e6\n\uf0f6\n+\uf0e7\n\uf0f7\n\uf0e7\n\uf0f7\n\uf0e8\n\uf0f8\n\uf0e8\n\uf0f8\n = 0.24"),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2024-02-03T23:13:08+05:30', 'source': '..\\data\\pdf\\2024 paper memory based.pdf', 'file_path': '..\\data\\pdf\\2024 paper memory based.pdf', 'total_pages': 17, 'format': 'PDF 1.7', 'title': '', 'author': 'PW MSO 256', 'subject': '', 'keywords': '', 'moddate': '2024-02-03T23:14:34+05:30', 'trapped': '', 'modDate': "D:20240203231434+05'30'", 'creationDate': "D:20240203231308+05'30'", 'page': 9}, page_content='PAGE \n9 \n \n             \n \nPW Mobile APP: https://smart.link/7wwosivoicgd4   \n  https://t.me/Gwcomsciandinfo \n                https://www.youtube.com/@GATEWallah_EE_EC_CS \n https://www.youtube.com/@GATEWallahbyPW \nDATA SCIENCE  & ARTIFICIAL INTELLIGENCE \n[MCQ] \nQ.17. \n2\n–1\nM = 3\n1\n\uf0e9\n\uf0f9\n\uf0ea\n\uf0fa\n\uf0eb\n\uf0fb\n \n \n(a) \nEigen values of M are +ve and real \n \n(b) \nEigen value of M non-negative and zero \n \n(c) \nEigen value of M are complex conjugates pair  \n \n \n(d) \nEigen value of M are negative and real. \nSol. \n(c) \n \n2\n–1\nM\n3\n1\n\uf0e9\n\uf0f9\n= \uf0ea\n\uf0fa\n\uf0eb\n\uf0fb\n \n \nCalculating the eigen value of M we get  \n \nM – λI |\n2 –\n–1\n0\n3\n1–\n\uf06c\n\uf0e9\n\uf0f9\n=\n=\n\uf0ea\n\uf0fa\n\uf06c\n\uf0eb\n\uf0fb\n \n \n2 –\n–1\n0\n3\n1–\n\uf06c\n=\n\uf06c\n \n \n(2 – λ) (1 – λ) + 3 = 0 \n \n2 – 2 λ – λ + λ2 + 3 = 0 \n \nλ2 –  3λ + 5 = 0 \n \nD = 9 – 20 \n \nD < 0 \n \nThus eigen values will be complex conjugates. \n \n[NAT] \nQ.18. f : R \uf0ae R is a function from R to R such that at some x*\uf0ce R, f’(x*) = 0  \n \nf” (x*) > 0, thus of necessarily has a  \nSol. \n(Local Minima) \n \nf will have a local minima a at x* as f’(x*) = 0 denotes that x* is a critical point. Now \nas the double derivative of at (x*) is greater than 0, thus the function will have a local \nminima at x = x* \uf0ce R'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2024-02-03T23:13:08+05:30', 'source': '..\\data\\pdf\\2024 paper memory based.pdf', 'file_path': '..\\data\\pdf\\2024 paper memory based.pdf', 'total_pages': 17, 'format': 'PDF 1.7', 'title': '', 'author': 'PW MSO 256', 'subject': '', 'keywords': '', 'moddate': '2024-02-03T23:14:34+05:30', 'trapped': '', 'modDate': "D:20240203231434+05'30'", 'creationDate': "D:20240203231308+05'30'", 'page': 10}, page_content='PAGE \n10 \n \n             \n \nPW Mobile APP: https://smart.link/7wwosivoicgd4   \n  https://t.me/Gwcomsciandinfo \n                https://www.youtube.com/@GATEWallah_EE_EC_CS \n https://www.youtube.com/@GATEWallahbyPW \nDATA SCIENCE  & ARTIFICIAL INTELLIGENCE \n[NAT] \nQ.19. Match the following: \n \n(p) Discrimination \n(i)PCA.         \n(q) Dimentionality Reduction \n(ii)Naive Baye.    \n(r) Generative Model \n(iii) Logistic Regression. \nSol. \n \n(i) \nPCA     \n \n(q) \nDimentionality Reduction  \n(ii) \nNaive Baye.     \n \n(p) \nDiscrimination \n \n(iii) Logistic Regression.   \n(r) \nGenerative Model  \n[MCQ] \nQ.20. Three fair coins are tossed independently. T is the event that two or more tosses result \nin heads. S is the event that two or more tosses result in tails. The probability of the \nevent T ∩ S is – \n \n(a) \n0.5 \n(b) \n0 \n \n(c) \n0.25 \n(d) \n1 \nSol. \n(b) \n \nExample space for tossing three fair coins independently is \n \nHHH, HHT, HTT, TTT, TTH, THT, THH, \n \nNow, T = {HHT, HHH, HTH, THH} \n \nS = {HTT, TTT, TTH, THT} \n \nP(T∩S) = (\n)\n( )\nn T\nS\nn S\n\uf0c7\n \n \nT ∩ S = ϕ  \n \nN (T ∩ S) = 0 \n \nP (T ∩ S) = 0\n0\n8 =\n \n \n[MCQ] \nQ.21. Consider two events T & S. Let T denotes compliment of event T. The probability \nassociated with different event are given as follows: \n \nP(T ) = 0.6 \n \nP(S/T) = 0.3 \n \nP(S/T ) = 0.6 \n \nP(T/S) = ? \n \n(a) \n0.25 \n(b) \n1 \n \n(c) \n0.75 \n(d) \n0.5'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2024-02-03T23:13:08+05:30', 'source': '..\\data\\pdf\\2024 paper memory based.pdf', 'file_path': '..\\data\\pdf\\2024 paper memory based.pdf', 'total_pages': 17, 'format': 'PDF 1.7', 'title': '', 'author': 'PW MSO 256', 'subject': '', 'keywords': '', 'moddate': '2024-02-03T23:14:34+05:30', 'trapped': '', 'modDate': "D:20240203231434+05'30'", 'creationDate': "D:20240203231308+05'30'", 'page': 11}, page_content='PAGE \n11 \n \n             \n \nPW Mobile APP: https://smart.link/7wwosivoicgd4   \n  https://t.me/Gwcomsciandinfo \n                https://www.youtube.com/@GATEWallah_EE_EC_CS \n https://www.youtube.com/@GATEWallahbyPW \nDATA SCIENCE  & ARTIFICIAL INTELLIGENCE \nSol. \n(a) \n \n( )\nP T\n0.6\n=\n,  \n \n1 – P(T) = 0.6 \n \nP(T) = 0.4 \n \n \nP(S/T) + (\n)\n( )\nP S\nT\nP T\n\uf0c7\n \n \n(\n)\n0.3 0.4\nP S\nT\n\uf0b4\n=\n\uf0c7\n \n \n(\n)\nP S\nT\n0.12\n\uf0c7\n=\n \n \n(\n)\n( )\nP S\nT\nS\nP T\nP T\n\uf0c7\n\uf0e6\n\uf0f6=\n\uf0e7\n\uf0f7\n\uf0e8\n\uf0f8\n \n \n(\n)\nP S\nT\n0.6 0.6\n0.36\n\uf0c7\n=\n\uf0b4\n=\n \n \nNow  \n \n \n \n(\n)(\n)\nS\nT S\nT\nS\n\uf0c7\n\uf0c7\n=\n \n \n(\n)(\n)\n\uf07b\n\uf07d\n\uf05b\uf05d\nP\nS\nT S\nT\nP S\n\uf0c7\n\uf0c7\n=\n \n \nP (A + B) = P (A) + P (B) – P (A ∩ B) \n \nNow \n \n(\n) (\n)\n(\n) (\n)\n( )\nP S\nT\nS\nT\nP S\nT\nS\nT\nF S\n\uf0c7\n+\n\uf0c7\n=\n\uf0c7\n+\n\uf0c7\n=\n \n \n0.12 + 0.36 – (\n)\n( )\nP S\nT\nT\nC\nF S\n\uf0c7\n\uf0c7\n\uf0c7\n=\n \n \n0.48 – P (∩ (ϕ ∩ S)) = P(S) \n \n0.48 – P (S ∩ ϕ) = P(S) \n \n0.48 – P (ϕ) = P(S̅ ) \n \nP(S) = 0.48 \n \n(\n)\n( )\n1\nP S\nT\nT\n0.12\nP\nt\n0.25\nS\nP S\n0.48\n\uf0c7\n\uf0e6\n\uf0f6=\n=\n=\n=\n\uf0e7\n\uf0f7\n\uf0e8\n\uf0f8\n \n \n \n[MCQ] \nQ.22. \n( )\nx\nx\ne\n0\nf\n0\nother\nx\nx\n−\uf06c\n\uf0ec\n\uf0fc\n\uf06c\n\uf0b3\n\uf0ef\n\uf0ef\n= \uf0ed\n\uf0fd\n\uf0ef\n\uf0ef\n\uf0ee\n\uf0fe\n \n \nIf 5E(x) = Var (x), E(x) & Var (x) indicate the expectation and variance of x the value \nof \uf06c is ______. \n \n \n(a) \n1/5 \n(b) \n1/2 \n \n(c) \n2/5 \n(d) \n2'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2024-02-03T23:13:08+05:30', 'source': '..\\data\\pdf\\2024 paper memory based.pdf', 'file_path': '..\\data\\pdf\\2024 paper memory based.pdf', 'total_pages': 17, 'format': 'PDF 1.7', 'title': '', 'author': 'PW MSO 256', 'subject': '', 'keywords': '', 'moddate': '2024-02-03T23:14:34+05:30', 'trapped': '', 'modDate': "D:20240203231434+05'30'", 'creationDate': "D:20240203231308+05'30'", 'page': 12}, page_content='PAGE \n12 \n \n             \n \nPW Mobile APP: https://smart.link/7wwosivoicgd4   \n  https://t.me/Gwcomsciandinfo \n                https://www.youtube.com/@GATEWallah_EE_EC_CS \n https://www.youtube.com/@GATEWallahbyPW \nDATA SCIENCE  & ARTIFICIAL INTELLIGENCE \nSol. \n(a) \n \n( )\n– x\nx\ne\nx\n0\nf\nx\n0\notherwise\n\uf06c\n\uf0ec\n\uf0fc\n\uf06c\n\uf03e\n\uf0ef\n\uf0ef\n= \uf0ed\n\uf0fd\n\uf0ef\n\uf0ef\n\uf0ee\n\uf0fe\n \n \nIf 5E(X) = var (x) have E(x) denotes the expectation of x and var(x) denotes the \nvariance of x, then the values of λ is ___ \n \nE(X) = \n( )\nx\n–\nx f\nx\ndx\n\uf0a5\n\uf0a5\n\uf0d7\n\uf0d7\n\uf0f2\n \n \nVar(x) = E(x2) – (E(x))2 \n \n(\n)\n( )\n2\n2\nx\n–\nE x\nx f\nx\ndx\n\uf0a5\n\uf0a5\n=\n\uf0d7\n\uf0f2\n \n \nx\nx\n0\nx\nx\n0\nx\nx\n2\n0\nE(x)\nxf (x)dx\nxe\ndx\nxe\ne\ndx\n1\ne\ne\nx\n1\n\uf0a5\n−\uf0a5\n\uf0a5\n−\uf06c\n\uf0a5\n−\uf06c\n−\uf06c\n\uf0a5\n−\uf06c\n−\uf06c\n=\n\uf06c\n\uf0e9\n\uf0f9\n= \uf06c\n−\n\uf0ea\n\uf0fa\n−\uf06c\n−\uf06c\n\uf0eb\n\uf0fb\n\uf0e9\n\uf0f9\n−\n= \uf06c\n−\n\uf0ea\n\uf0fa\n\uf06c\n\uf06c\n\uf0eb\n\uf0fb\n= \uf06c\n\uf0f2\n\uf0f2\n\uf0f2\n \n \n2\n2\nx\nx\nx\n2\n0\n2\n2\nE(x )\nx f (x)dx\ne\ne\nx\n2x\ndx\n2\n1\n2\n\uf0a5\n−\uf0a5\n\uf0a5\n−\uf06c\n−\uf06c\n=\n\uf0e9\n\uf0f9\n= \uf06c\n−\n\uf0ea\n\uf0fa\n−\uf06c\n−\uf06c\n\uf0eb\n\uf0fb\n\uf0e6\n\uf0f6\n= \uf06c\n\uf0b4\n=\n\uf0e7\n\uf0f7\n\uf06c\n\uf06c\n\uf06c\n\uf0e8\n\uf0f8\n\uf0f2\n\uf0f2\n \n \n2\n2\nVar(x)\nE(x )\n(E(x))\n=\n−\n \n \n2\n2\n2\n2\n1\n1\n\uf0e6\n\uf0f6\n=\n−\n=\n\uf0e7\n\uf0f7\n\uf06c\n\uf06c\n\uf06c\n\uf0e8\n\uf0f8\n \n \n2\nVar(x)\n5E(x)\n1\n5\n=\n=\n\uf06c\n\uf06c\n \n \n(5\n1)\n1\n5\n\uf06c\uf06c−\n\uf06c='),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2024-02-03T23:13:08+05:30', 'source': '..\\data\\pdf\\2024 paper memory based.pdf', 'file_path': '..\\data\\pdf\\2024 paper memory based.pdf', 'total_pages': 17, 'format': 'PDF 1.7', 'title': '', 'author': 'PW MSO 256', 'subject': '', 'keywords': '', 'moddate': '2024-02-03T23:14:34+05:30', 'trapped': '', 'modDate': "D:20240203231434+05'30'", 'creationDate': "D:20240203231308+05'30'", 'page': 13}, page_content='PAGE \n13 \n \n             \n \nPW Mobile APP: https://smart.link/7wwosivoicgd4   \n  https://t.me/Gwcomsciandinfo \n                https://www.youtube.com/@GATEWallah_EE_EC_CS \n https://www.youtube.com/@GATEWallahbyPW \nDATA SCIENCE  & ARTIFICIAL INTELLIGENCE \n[MCQ] \nQ.23. Probability to get a boy & girl is 1/2 if A man has three children, the probability to get \n2 girls and 1 boy. \n \n(a) \n1\n8  \n(b) \n2\n8  \n \n(c) \n3\n8  \n(d) \n1\n2  \nSol. \n(b) \n \nThe probability to get a boy and girl is 1\n2 . A man has three children, the probability to \nget 2 girl and 1 boy is___. \n \nS = {BBB, GGG, BBG, GGB} \n \nn(S) = 4 \n \nP(E) = n(E)\n1\n2\nn(S)\n4\n8\n=\n=\n \n[NAT] \nQ.24. Consider the following relations Raider and Team managed by Kabaddi as follows: \n \nRaider \nID \nName  \nRaids \nRaid Point \n1 \n- \n200 \n250 \n2 \n- \n190 \n219 \n3 \n- \n150 \n200 \n4 \n- \n150 \n190 \n5 \n- \n175 \n220 \n6 \n- \n193 \n215 \n \nTeam \nCity \nID  \nBid point \nJaipur \n2 \n200 \n- \n3 \n195 \n- \n5 \n175 \nJaipur \n1 \n250 \n- \n4 \n200 \nJaipur \n6 \n200 \n \nSelect * FROM Raider Team WHERE Raider .ID = Team. ID and City = “Jaipur” and \nRaid point > 200.'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2024-02-03T23:13:08+05:30', 'source': '..\\data\\pdf\\2024 paper memory based.pdf', 'file_path': '..\\data\\pdf\\2024 paper memory based.pdf', 'total_pages': 17, 'format': 'PDF 1.7', 'title': '', 'author': 'PW MSO 256', 'subject': '', 'keywords': '', 'moddate': '2024-02-03T23:14:34+05:30', 'trapped': '', 'modDate': "D:20240203231434+05'30'", 'creationDate': "D:20240203231308+05'30'", 'page': 14}, page_content='PAGE \n14 \n \n             \n \nPW Mobile APP: https://smart.link/7wwosivoicgd4   \n  https://t.me/Gwcomsciandinfo \n                https://www.youtube.com/@GATEWallah_EE_EC_CS \n https://www.youtube.com/@GATEWallahbyPW \nDATA SCIENCE  & ARTIFICIAL INTELLIGENCE \nSol. \n(3) \n \nRaider × Team [Cross product] \n \nId \nName \nRaids \nRaids Point City \nBid point \n1 \n \n200 \n250 \nJaipur 250 \n2 \n \n190 \n219 \nJaipur 200 \n3 \n \n150 \n200 \n- \n195 \n4 \n \n150 \n190 \n- \n200 \n5 \n \n175 \n220 \n- \n175 \n6 \n \n193 \n215 \nJaipur 200 \n \nThe output will contain tuples where ‘Raider ID’ = Team \uf0d7 ID  and City = “Jaipur”  \n \nThe final output relation will consist of 3 tuples. \n[MCQ] \nQ.25. \nX,Y\n2xy 0\nx\n2\nf\n(x,y)\n0\ny\nx\n0\notherwise\n\uf03c\n\uf03c\n\uf0ec\n\uf0fc\n\uf0ef\n\uf0ef\n=\n\uf03c\n\uf03c\n\uf0ed\n\uf0fd\n\uf0ef\n\uf0ef\n\uf0ee\n\uf0fe\nfind E[Y| x\n1.5]\n=\n= \n \n(a) \n1 \n(b) \n2 \n \n(c) \n3 \n(d) \n4 \nSol. \n(a) \n \nY/X\nE[Y| X\nx]\nyf\n(y / x)dy\n\uf0a5\n−\uf0a5\n=\n= \uf0f2\n \n \nX,Y\nY/X\nX\nf\n(x,y)\nf\n(y / x)\nf (x)\n=\n \n \n,\n( )\n( , )\nX\nX Y\nf\nx\nf\nx y dy\n\uf0a5\n−\uf0a5\n= \uf0f2\n \n \nfX (x) = 0 \nfor \nx \uf0a3 0,   x \uf0b3 2. \n \n,\n0\n( )\n( , )\nx\nX\nX Y\nf\nx\nf\nx y dy\n=\uf0f2\n \n0 < x < 2 \n \n2\n3\n0\n0\n( )\n2\n2\n2\nx\nx\nX\ny\nf\nx\nxy dy\nx\nx\n\uf0e9\n\uf0f9\n=\n=\n=\n\uf0ea\n\uf0fa\n\uf0ea\n\uf0fa\n\uf0eb\n\uf0fb\n\uf0f2\n \n \nNow,  \n,\n/\n( , )\n( )\nX Y\nY X\nX\nf\nx y\ny\nf\nx\nf\nx\n\uf0e6\n\uf0f6=\n\uf0e7\n\uf0f7\n\uf0e8\n\uf0f8\n \n \n/\n0\nY X\ny\nf\nx\n\uf0e6\n\uf0f6=\n\uf0e7\n\uf0f7\n\uf0e8\n\uf0f8\n  \nfor \n0,\n2\n0\nx\nx\ny\nx\ny\n\uf0a3\n\uf0b3\n\uf0b3\n\uf03c'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2024-02-03T23:13:08+05:30', 'source': '..\\data\\pdf\\2024 paper memory based.pdf', 'file_path': '..\\data\\pdf\\2024 paper memory based.pdf', 'total_pages': 17, 'format': 'PDF 1.7', 'title': '', 'author': 'PW MSO 256', 'subject': '', 'keywords': '', 'moddate': '2024-02-03T23:14:34+05:30', 'trapped': '', 'modDate': "D:20240203231434+05'30'", 'creationDate': "D:20240203231308+05'30'", 'page': 15}, page_content='PAGE \n15 \n \n             \n \nPW Mobile APP: https://smart.link/7wwosivoicgd4   \n  https://t.me/Gwcomsciandinfo \n                https://www.youtube.com/@GATEWallah_EE_EC_CS \n https://www.youtube.com/@GATEWallahbyPW \nDATA SCIENCE  & ARTIFICIAL INTELLIGENCE \n \n/\n3\n2\nY X\ny\nxy\nf\nx\nx\n\uf0e6\n\uf0f6=\n\uf0e7\n\uf0f7\n\uf0e8\n\uf0f8\n \nfor \n0\n2\n0\nx\ny\nx\n\uf03c\n\uf03c\n\uf03c\n\uf03c\n \n \n/\n2\n2\nY X\ny\ny\nf\nx\nx\n\uf0e6\n\uf0f6=\n\uf0e7\n\uf0f7\n\uf0e8\n\uf0f8\n \n \nNow, \n/\nY X\nY\ny\nE\nyf\ndy\nX\nx\nx\n\uf0a5\n−\uf0a5\n\uf0e9\n\uf0f9\n\uf0e6\n\uf0f6\n=\n\uf0e7\n\uf0f7\n\uf0ea\n\uf0fa\n=\n\uf0e8\n\uf0f8\n\uf0eb\n\uf0fb\uf0f2\n \n \n2\n0\n2\nx\nY\ny\nE\ny\ndy\nX\nx\nx\n\uf0e9\n\uf0f9=\n\uf0ea\n\uf0fa\n=\n\uf0eb\n\uf0fb\uf0f2\n \nfor \n0 < x < 2 only \n \n3\n2\n0\n2\n3\n3\nx\nY\ny\nE\nx\nX\nx\nx\n\uf0e9\n\uf0f9\n\uf0e9\n\uf0f9\n\uf032\n=\n=\n\uf0ea\n\uf0fa\n\uf0ea\n\uf0fa\n=\n\uf0ea\n\uf0fa\n\uf0eb\n\uf0fb\n\uf0eb\n\uf0fb\n \nfor \n0 < x < 2 \n \n \nNow, \n2\n1.5\n1.5 1\n3\nY\nE X\n\uf0e9\n\uf0f9\n=\n=\n\uf0b4\n=\n\uf0ea\n\uf0fa\n\uf0eb\n\uf0fb\n \n \n \n\uf072\uf072\uf072'),
#  Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2024-02-03T23:13:08+05:30', 'source': '..\\data\\pdf\\2024 paper memory based.pdf', 'file_path': '..\\data\\pdf\\2024 paper memory based.pdf', 'total_pages': 17, 'format': 'PDF 1.7', 'title': '', 'author': 'PW MSO 256', 'subject': '', 'keywords': '', 'moddate': '2024-02-03T23:14:34+05:30', 'trapped': '', 'modDate': "D:20240203231434+05'30'", 'creationDate': "D:20240203231308+05'30'", 'page': 16}, page_content='THANK\nYOU\nTHANK\nYOU\nSOLDIERS'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2024-02-08T17:54:08+05:30', 'source': '..\\data\\pdf\\2024 Paper.pdf', 'file_path': '..\\data\\pdf\\2024 Paper.pdf', 'total_pages': 41, 'format': 'PDF 1.7', 'title': '', 'author': 'Admin', 'subject': '', 'keywords': '', 'moddate': '2024-02-08T17:54:08+05:30', 'trapped': '', 'modDate': "D:20240208175408+05'30'", 'creationDate': "D:20240208175408+05'30'", 'page': 0}, page_content='Data Science and Artificial Intelligence (DA) \nPage 1 of 41 \nOrganizing Institute: IISc Bengaluru \nGeneral Aptitude (GA)  \nQ.1 – Q.5 Carry ONE mark Each \nQ.1 \nIf ‘→’ denotes increasing order of intensity, then the meaning of the words  \n[sick → infirm → moribund] is analogous to [silly → _______ → daft]. \nWhich one of the given options is appropriate to fill the blank? \n \n \n(A) \nfrown \n(B) \nfawn \n(C) \nvein \n(D) \nvain'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2024-02-08T17:54:08+05:30', 'source': '..\\data\\pdf\\2024 Paper.pdf', 'file_path': '..\\data\\pdf\\2024 Paper.pdf', 'total_pages': 41, 'format': 'PDF 1.7', 'title': '', 'author': 'Admin', 'subject': '', 'keywords': '', 'moddate': '2024-02-08T17:54:08+05:30', 'trapped': '', 'modDate': "D:20240208175408+05'30'", 'creationDate': "D:20240208175408+05'30'", 'page': 1}, page_content='Data Science and Artificial Intelligence (DA) \nPage 2 of 41 \nOrganizing Institute: IISc Bengaluru \nQ.2 \nThe 15 parts of the given figure are to be painted such that no two adjacent parts \nwith shared boundaries (excluding corners) have the same color. The minimum \nnumber of colors required is \n \n \n \n(A) \n4 \n(B) \n3 \n(C) \n5 \n(D) \n6'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2024-02-08T17:54:08+05:30', 'source': '..\\data\\pdf\\2024 Paper.pdf', 'file_path': '..\\data\\pdf\\2024 Paper.pdf', 'total_pages': 41, 'format': 'PDF 1.7', 'title': '', 'author': 'Admin', 'subject': '', 'keywords': '', 'moddate': '2024-02-08T17:54:08+05:30', 'trapped': '', 'modDate': "D:20240208175408+05'30'", 'creationDate': "D:20240208175408+05'30'", 'page': 2}, page_content='Data Science and Artificial Intelligence (DA) \nPage 3 of 41 \nOrganizing Institute: IISc Bengaluru \nQ.3 \nHow many 4-digit positive integers divisible by 3 can be formed using only the \ndigits {1, 3,4, 6, 7}, such that no digit appears more than once in a number? \n \n \n(A) \n24 \n(B) \n48 \n(C) \n72 \n(D) \n12 \n \n \nQ.4 \nThe sum of the following infinite series is \n2 + 1\n2 + 1\n3 + 1\n4 + 1\n8 + 1\n9 + 1\n16 + 1\n27 + ⋯ \n \n \n(A) \n11/3 \n(B) \n7/2 \n(C) \n13/4 \n(D) \n9/2'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2024-02-08T17:54:08+05:30', 'source': '..\\data\\pdf\\2024 Paper.pdf', 'file_path': '..\\data\\pdf\\2024 Paper.pdf', 'total_pages': 41, 'format': 'PDF 1.7', 'title': '', 'author': 'Admin', 'subject': '', 'keywords': '', 'moddate': '2024-02-08T17:54:08+05:30', 'trapped': '', 'modDate': "D:20240208175408+05'30'", 'creationDate': "D:20240208175408+05'30'", 'page': 3}, page_content='Data Science and Artificial Intelligence (DA) \nPage 4 of 41 \nOrganizing Institute: IISc Bengaluru \nQ.5 \nIn an election, the share of valid votes received by the four candidates A, B, C, and \nD is represented by the pie chart shown. The total number of votes cast in the \nelection were 1,15,000, out of which 5,000 were invalid.  \n \nBased on the data provided, the total number of valid votes received by the \ncandidates B and C is \n \n \n(A) \n45,000 \n(B) \n49,500 \n(C) \n51,750 \n(D) \n54,000 \n \n \n \n \n \n \n \n \nA\n40%\nB\n25%\nC\n20%\nD\n15%\nShare of valid votes'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2024-02-08T17:54:08+05:30', 'source': '..\\data\\pdf\\2024 Paper.pdf', 'file_path': '..\\data\\pdf\\2024 Paper.pdf', 'total_pages': 41, 'format': 'PDF 1.7', 'title': '', 'author': 'Admin', 'subject': '', 'keywords': '', 'moddate': '2024-02-08T17:54:08+05:30', 'trapped': '', 'modDate': "D:20240208175408+05'30'", 'creationDate': "D:20240208175408+05'30'", 'page': 4}, page_content='Data Science and Artificial Intelligence (DA) \nPage 5 of 41 \nOrganizing Institute: IISc Bengaluru \nQ.6 – Q.10 Carry TWO marks Each \nQ.6 \nThousands of years ago, some people began dairy farming. This coincided with a \nnumber of mutations in a particular gene that resulted in these people developing \nthe ability to digest dairy milk. \nBased on the given passage, which of the following can be inferred? \n \n \n(A) \nAll human beings can digest dairy milk. \n(B) \nNo human being can digest dairy milk. \n(C) \nDigestion of dairy milk is essential for human beings. \n(D) \nIn human beings, digestion of dairy milk resulted from a mutated gene. \n \n \nQ.7 \nThe probability of a boy or a girl being born is 1/2. For a family having only \nthree children, what is the probability of having two girls and one boy? \n \n \n(A) \n3/8 \n(B) \n1/8 \n(C) \n1/4 \n(D) \n1/2'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2024-02-08T17:54:08+05:30', 'source': '..\\data\\pdf\\2024 Paper.pdf', 'file_path': '..\\data\\pdf\\2024 Paper.pdf', 'total_pages': 41, 'format': 'PDF 1.7', 'title': '', 'author': 'Admin', 'subject': '', 'keywords': '', 'moddate': '2024-02-08T17:54:08+05:30', 'trapped': '', 'modDate': "D:20240208175408+05'30'", 'creationDate': "D:20240208175408+05'30'", 'page': 5}, page_content='Data Science and Artificial Intelligence (DA) \nPage 6 of 41 \nOrganizing Institute: IISc Bengaluru \nQ.8 \nPerson 1 and Person 2 invest in three mutual funds A, B, and C. The amounts they \ninvest in each of these mutual funds are given in the table. \n \nMutual fund A \nMutual fund B \nMutual fund C \nPerson 1 \n₹10,000 \n₹20,000 \n₹20,000 \nPerson 2 \n₹20,000 \n₹15,000 \n₹15,000 \nAt the end of one year, the total amount that Person 1 gets is ₹500 more than \nPerson 2. The annual rate of return for the mutual funds B and C is 15% each. What \nis the annual rate of return for the mutual fund A? \n \n \n(A) \n7.5% \n(B) \n10% \n(C) \n15% \n(D) \n20%'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2024-02-08T17:54:08+05:30', 'source': '..\\data\\pdf\\2024 Paper.pdf', 'file_path': '..\\data\\pdf\\2024 Paper.pdf', 'total_pages': 41, 'format': 'PDF 1.7', 'title': '', 'author': 'Admin', 'subject': '', 'keywords': '', 'moddate': '2024-02-08T17:54:08+05:30', 'trapped': '', 'modDate': "D:20240208175408+05'30'", 'creationDate': "D:20240208175408+05'30'", 'page': 6}, page_content='Data Science and Artificial Intelligence (DA) \nPage 7 of 41 \nOrganizing Institute: IISc Bengaluru \nQ.9 \nThree different views of a dice are shown in the figure below.  \n \nThe piece of paper that can be folded to make this dice is  \n \n \n(A) \n \n(B) \n \n(C) \n \n(D)'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2024-02-08T17:54:08+05:30', 'source': '..\\data\\pdf\\2024 Paper.pdf', 'file_path': '..\\data\\pdf\\2024 Paper.pdf', 'total_pages': 41, 'format': 'PDF 1.7', 'title': '', 'author': 'Admin', 'subject': '', 'keywords': '', 'moddate': '2024-02-08T17:54:08+05:30', 'trapped': '', 'modDate': "D:20240208175408+05'30'", 'creationDate': "D:20240208175408+05'30'", 'page': 7}, page_content='Data Science and Artificial Intelligence (DA) \nPage 8 of 41 \nOrganizing Institute: IISc Bengaluru \nQ.10 \nVisualize two identical right circular cones such that one is inverted over the other \nand they share a common circular base. If a cutting plane passes through the vertices \nof the assembled \ncones, what shape does the outer boundary \nof the  \nresulting cross-section make?  \n \n \n(A) \nA rhombus \n(B) \nA triangle \n(C) \nAn ellipse \n(D) \nA hexagon'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2024-02-08T17:54:08+05:30', 'source': '..\\data\\pdf\\2024 Paper.pdf', 'file_path': '..\\data\\pdf\\2024 Paper.pdf', 'total_pages': 41, 'format': 'PDF 1.7', 'title': '', 'author': 'Admin', 'subject': '', 'keywords': '', 'moddate': '2024-02-08T17:54:08+05:30', 'trapped': '', 'modDate': "D:20240208175408+05'30'", 'creationDate': "D:20240208175408+05'30'", 'page': 8}, page_content='Data Science and Artificial Intelligence (DA) \nPage 9 of 41 \nOrganizing Institute: IISc Bengaluru \nQ.11 – Q.35 Carry ONE mark Each \n \nQ.11 \nConsider the following statements: \n(i) \nThe mean and variance of a Poisson random variable are equal. \n(ii) \nFor a standard normal random variable, the mean is zero and the \nvariance is one. \nWhich ONE of the following options is correct?  \n(A) \nBoth (i) and (ii) are true \n(B) \n(i) is true and (ii) is false \n(C) \n(ii) is true and (i) is false \n(D) \nBoth (i) and (ii) are false \n \nQ.12 \nThree fair coins are tossed independently. T is the event that two or more tosses \nresult in heads. S is the event that two or more tosses result in tails.  \nWhat is the probability of the event 𝑇∩𝑆 ? \n(A) \n0 \n(B) \n0.5 \n(C) \n0.25 \n(D) \n1'),
#  Document(metadata={'producer': 'Microsoft® Word 2019', 'creator': 'Microsoft® Word 2019', 'creationdate': '2024-02-08T17:54:08+05:30', 'source': '..\\data\\pdf\\2024 Paper.pdf', 'file_path': '..\\data\\pdf\\2024 Paper.pdf', 'total_pages': 41, 'format': 'PDF 1.7', 'title': '', 'author': 'Admin', 'subject': '', 'keywords': '', 'moddate': '2024-02-08T17:54:08+05:30', 'trapped': '', 'modDate': "D:20240208175408+05'30'", 'creationDate': "D:20240208175408+05'30'", 'page': 9}, page_content='Data Science and Artificial Intelligence (DA) \nPage 10 of 41 \nOrganizing Institute: IISc Bengaluru \nQ.13 \nConsider the matrix 𝑴= [2\n−1\n3\n1 ].  \nWhich ONE of the following statements is TRUE? \n(A) \nThe eigenvalues of 𝑴 are non-negative and real. \n(B) \nThe eigenvalues of 𝑴 are complex conjugate pairs. \n(C) \nOne eigenvalue of 𝑴 is positive and real, and another eigenvalue of 𝑴 is zero.  \n(D) \nOne eigenvalue of 𝑴 is non-negative and real, and another eigenvalue of 𝑴 is \nnegative and real.  \n \nQ.14 \nConsider performing depth-first search (DFS) on an undirected and unweighted \ngraph G starting at vertex 𝑠. For any vertex 𝑢 in G, 𝑑[𝑢] is the length of the shortest \npath from 𝑠 to 𝑢. Let (𝑢, 𝑣) be an edge in G such that 𝑑[𝑢] < 𝑑[𝑣]. If the edge \n(𝑢, 𝑣) is explored first in the direction from 𝑢 to 𝑣 during the above DFS, then (𝑢, 𝑣) \nbecomes a ______ edge. \n(A) \ntree  \n(B) \ncross  \n(C) \nback \n(D) \ngray'),
# ...
#  Document(metadata={'producer': 'Microsoft: Print To PDF', 'creator': '', 'creationdate': '2023-11-08T15:43:22+05:30', 'source': '..\\data\\pdf\\2024 sample paper.pdf', 'file_path': '..\\data\\pdf\\2024 sample paper.pdf', 'total_pages': 29, 'format': 'PDF 1.7', 'title': 'Microsoft Word - DASampleQuestionPaperFinal', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2023-11-08T15:43:22+05:30', 'trapped': '', 'modDate': "D:20231108154322+05'30'", 'creationDate': "D:20231108154322+05'30'", 'page': 19}, page_content='GATE 2024 -- Data Science and Artificial Intelligence (DA) -- Sample Question Paper \nDA \n                                                                                                                    Page 20 of 29 \n \nQ.35 \nConsider the following statements: \n(P): A smooth twice differentiable function can have a global minimum. \n(Q): All smooth twice differentiable functions have a global minimum. \n(A) \nP and Q are true. \n(B) \nP is true and Q is false. \n(C) \nP is false and Q is true. \n(D) \nP and Q are false. \n \nQ.36 \nConsider the following joint distribution of random variables X and Y:  \n𝑓(𝑥, 𝑦) = ቐ\n𝑥(1 + 3𝑦ଶ)\n4\n,   0 ≤𝑥≤2, 0 ≤𝑦≤1\n0,   𝑜𝑡ℎ𝑒𝑟𝑤𝑖𝑠𝑒\n  \nWhich of the following is the conditional pdf of X|Y? \n(A) \n௫\nସ\n(B) \n௬\nସ\n(C) \n௫\nଶ\n(D) \n௬\nଶ'),
#  Document(metadata={'producer': 'Microsoft: Print To PDF', 'creator': '', 'creationdate': '2023-11-08T15:43:22+05:30', 'source': '..\\data\\pdf\\2024 sample paper.pdf', 'file_path': '..\\data\\pdf\\2024 sample paper.pdf', 'total_pages': 29, 'format': 'PDF 1.7', 'title': 'Microsoft Word - DASampleQuestionPaperFinal', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2023-11-08T15:43:22+05:30', 'trapped': '', 'modDate': "D:20231108154322+05'30'", 'creationDate': "D:20231108154322+05'30'", 'page': 20}, page_content='GATE 2024 -- Data Science and Artificial Intelligence (DA) -- Sample Question Paper \nDA \n                                                                                                                    Page 21 of 29 \n \nQ.37 \nFor the matrix 𝐻= ቂ3\n−1\n−1\n3 ቃ, one of the eigenvectors is [−1 −1 ]்.  \nThe other eigenvector is  \n(A) \n[1 −1 ]் \n(B) \n[1 1 ]் \n(C) \n[1 0 ]் \n(D) \n [0 1 ]் \n \nQ.38 \nThe following statements are made regarding a matrix Am x n. \nP. The column space is orthogonal to the row space. \nQ. The column space is orthogonal to the left null space. \nR. The row space is orthogonal to the null space. \nT.  The null space is orthogonal to the left null space.   \nWhich of the following statements are true? \n(A) \nP and Q only \n(B) \nP and R only \n(C) \nQ and R only \n(D) \nP and T only'),
#  Document(metadata={'producer': 'Microsoft: Print To PDF', 'creator': '', 'creationdate': '2023-11-08T15:43:22+05:30', 'source': '..\\data\\pdf\\2024 sample paper.pdf', 'file_path': '..\\data\\pdf\\2024 sample paper.pdf', 'total_pages': 29, 'format': 'PDF 1.7', 'title': 'Microsoft Word - DASampleQuestionPaperFinal', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2023-11-08T15:43:22+05:30', 'trapped': '', 'modDate': "D:20231108154322+05'30'", 'creationDate': "D:20231108154322+05'30'", 'page': 21}, page_content='GATE 2024 -- Data Science and Artificial Intelligence (DA) -- Sample Question Paper \nDA \n                                                                                                                    Page 22 of 29 \n \nQ.39 \nConsider a matrix      \u0d65\n0\n1\n0\n𝑎\n2\n𝑑\n𝑏\n3\n𝑐\n൩ .  The matrix cannot have rank                \n(A) \n0 \n(B) \n1 \n(C) \n2 \n(D) \n3 \n \n \n \n \nQ.40 \nA file with 100,000 records is indexed with B+ tree. If the size of a memory \nblock is 2K bytes, the size of a key is 4 bytes, the size of a pointer is 4 bytes, \nthe minimum possible height of the B+ tree index is ______. Height is always \ngreater than or equal to 1.               \nHints: No records are stored in the nodes, only keys are stored. The sizes of the \npointers are same, irrespective of whether they point to a node or a record. \n \nQ.41 \nConsider a schema R(A, B, C, D, E, F) and functional dependencies  \nA → B, C → D, and E → F. The number of superkeys of this schema is _____.'),
#  Document(metadata={'producer': 'Microsoft: Print To PDF', 'creator': '', 'creationdate': '2023-11-08T15:43:22+05:30', 'source': '..\\data\\pdf\\2024 sample paper.pdf', 'file_path': '..\\data\\pdf\\2024 sample paper.pdf', 'total_pages': 29, 'format': 'PDF 1.7', 'title': 'Microsoft Word - DASampleQuestionPaperFinal', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2023-11-08T15:43:22+05:30', 'trapped': '', 'modDate': "D:20231108154322+05'30'", 'creationDate': "D:20231108154322+05'30'", 'page': 22}, page_content='GATE 2024 -- Data Science and Artificial Intelligence (DA) -- Sample Question Paper \nDA \n                                                                                                                    Page 23 of 29 \n \nQ.42 \nGiven the dataset: (1, 1), (3, 3), (4, 4), (5, 5), (6, 6), (9, 9), (0, 3), (3, 0) and \nassuming the initial centroids for (𝐾= 3 – means clustering) to be \n𝐶ଵ= (3, 3), 𝐶ଶ= (5, 5) 𝑎𝑛𝑑 𝐶ଷ=  (6, 6). One iteration of the Expectation \nMaximization Algorithm for 𝐾-means clustering, will update 𝐶ଷ to (a, a). The \nvalue of a is ____ . \n \nQ.43 \nConsider a Multi-Layer Perceptron (MLP) model with one hidden layer and one \noutput layer. The hidden layer has 10 neurons, and the output layer has 3 neurons. \nThe input to the MLP is a 5-dimensional vector. Each neuron is connected to \nevery neuron in the previous layer, and a bias term is included for each neuron. \nThe activation function used is the sigmoid function. The total number of \ntrainable parameters in this MLP model is ______. \n \nQ.44 \n A company is manufacturing a product at the rate of P units per day. The cost \nper unit in Rs is  𝐶= 230 + 0.1𝑃+ 9000/𝑃. The selling prices per unit is Rs. \n300. The production level minimizing the cost per unit and the total profit per \nday, respectively, are \n(A) \n290, 3000 \n(B) \n150, 2500 \n(C) \n290, 2500 \n(D) \n150, 3000'),
#  Document(metadata={'producer': 'Microsoft: Print To PDF', 'creator': '', 'creationdate': '2023-11-08T15:43:22+05:30', 'source': '..\\data\\pdf\\2024 sample paper.pdf', 'file_path': '..\\data\\pdf\\2024 sample paper.pdf', 'total_pages': 29, 'format': 'PDF 1.7', 'title': 'Microsoft Word - DASampleQuestionPaperFinal', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2023-11-08T15:43:22+05:30', 'trapped': '', 'modDate': "D:20231108154322+05'30'", 'creationDate': "D:20231108154322+05'30'", 'page': 23}, page_content='GATE 2024 -- Data Science and Artificial Intelligence (DA) -- Sample Question Paper \nDA \n                                                                                                                    Page 24 of 29 \n \nQ.45 \nA class contains 60% of students who are incapable of changing their opinions \nabout anything, and 40% of students are changing their minds at random, with \nprobability 0.3, between subsequent votes on the same issue. Then, the \nprobability of a student randomly chosen voted twice in the same way is \n_______. \n \nQ.46 \nConsider the grid world shown in the figure below. \n \n \n  \n \n \nAn agent is planning to move from the starting location (𝑥௦, 𝑦௦) to the final \nlocation ൫𝑥\u0bd9, 𝑦\u0bd9൯. The obstacles along the path are triangular in form. Consider \nthe following heuristic functions to conduct A* search. \n− ℎ\u0bd6 assumes the obstacles are the smallest circles circumscribing the triangles.  \n− ℎ\u0be5 assumes the obstacles are smallest rectangles circumscribing the triangles. \n− ℎ\u0bd6′ assumes the obstacles are largest circles inscribed in the triangles. \n− ℎ\u0be5′ assumes the obstacles are largest rectangles inscribed the triangles. \nWhich of the following statement(s) is(are) true? \n(A) \nℎ\u0bd6 is an admissible heuristic \n(B) \nℎ\u0be5 is an admissible heuristic \n(C) \nℎ\u0bd6′ is an admissible heuristic \n(D) \nℎ\u0be5′ is an admissible heuristic'),
#  Document(metadata={'producer': 'Microsoft: Print To PDF', 'creator': '', 'creationdate': '2023-11-08T15:43:22+05:30', 'source': '..\\data\\pdf\\2024 sample paper.pdf', 'file_path': '..\\data\\pdf\\2024 sample paper.pdf', 'total_pages': 29, 'format': 'PDF 1.7', 'title': 'Microsoft Word - DASampleQuestionPaperFinal', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2023-11-08T15:43:22+05:30', 'trapped': '', 'modDate': "D:20231108154322+05'30'", 'creationDate': "D:20231108154322+05'30'", 'page': 24}, page_content='GATE 2024 -- Data Science and Artificial Intelligence (DA) -- Sample Question Paper \nDA \n                                                                                                                    Page 25 of 29 \n \nQ.47 \nLet {O1, O2, O3, O4} represent the possible outcomes of a random experiment, \nwith Pr({O1}) = Pr({O2}) = Pr({O3}) = Pr({O4}). Consider the following \nevents: P = {O1,O2}, Q = {O2,O3}, R = {O3,O4}, S = {O1,O2,O3}.  \nThen, which of the following statements are true?              \n(A) \nP and Q are independent \n(B) \nP and Q are not independent \n(C) \nR and S are independent \n(D) \nQ and S are not independent \n \nQ.48 \nConsider the matrix X whose eigenvalues are 1, ‒1  and 3. The Trace of X3 - \n3X2 is _______. \n \n \nQ.49 \nWhat is the output of the following python program? \n \ni = 1 \nj = 1 \nfor i in range(1, 11): \n  if i % 3 != 0: \n    j += 2 \n    continue \n  if j % 3 == 0: \n    break \n          print(i + j) \n(A) \n3 \n(B) \n5 \n(C) \n12 \n(D) \n15'),
#  Document(metadata={'producer': 'Microsoft: Print To PDF', 'creator': '', 'creationdate': '2023-11-08T15:43:22+05:30', 'source': '..\\data\\pdf\\2024 sample paper.pdf', 'file_path': '..\\data\\pdf\\2024 sample paper.pdf', 'total_pages': 29, 'format': 'PDF 1.7', 'title': 'Microsoft Word - DASampleQuestionPaperFinal', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2023-11-08T15:43:22+05:30', 'trapped': '', 'modDate': "D:20231108154322+05'30'", 'creationDate': "D:20231108154322+05'30'", 'page': 25}, page_content='GATE 2024 -- Data Science and Artificial Intelligence (DA) -- Sample Question Paper \nDA \n                                                                                                                    Page 26 of 29 \n \nQ.50 \nAssume that S is a stack and Q1 and Q2 are two Queues which support the \nEnqueue and Dequeue operations. Consider the following pseudo code for \nimplementing the Pop and Push operation on S. [Note: Swap(x,y) exchanges \nthe two queues x and y.] \n \nPush(S,x) \nA(Q2,x) \nwhile(Q1 not empty) \nB(Q2, C(Q1)); \nSwap(Q1, Q2) \n \nPop(S) \nreturn(D(Q1)) \nWhich of the following options for the functions A, B, C, and D correspond to \ncorrectly implementing the Push and Pop operations on the stack S?\n(A) \nA,B - Enqueue  C,D - Dequeue \n(B) \nA,C - Enqueue  B, D - Dequeue \n(C) \nA,C - Dequeue  B,D- Enqueue \n(D) \nA,D - Enqueue B,C - Dequeue'),
#  Document(metadata={'producer': 'Microsoft: Print To PDF', 'creator': '', 'creationdate': '2023-11-08T15:43:22+05:30', 'source': '..\\data\\pdf\\2024 sample paper.pdf', 'file_path': '..\\data\\pdf\\2024 sample paper.pdf', 'total_pages': 29, 'format': 'PDF 1.7', 'title': 'Microsoft Word - DASampleQuestionPaperFinal', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2023-11-08T15:43:22+05:30', 'trapped': '', 'modDate': "D:20231108154322+05'30'", 'creationDate': "D:20231108154322+05'30'", 'page': 26}, page_content='GATE 2024 -- Data Science and Artificial Intelligence (DA) -- Sample Question Paper \nDA \n                                                                                                                    Page 27 of 29 \n \nQ.51 \nConsider the following python program. \nimport math \n  def fun(a, b, d): \n    n1 = 0 \n    n2 = 0 \n    flag = 1 \n    for i in range(d): \n        n1 = n1 + (a[i] * a[i]) \n        n2 = n2 + (b[i] * b[i]) \n    for i in range(d): \n        a[i] = a[i]/math.sqrt(n1) \n        b[i] = b[i]/math.sqrt(n2) \n    for i in range(d): \n        if a[i] != b[i]: \n            flag = 0 \n            break \n    return flag \nFor which of the following inputs does the above algorithm produce 1 as an \noutput? \n(P) a = [1,2,3,4]; b = [3,4,5,6], d = 4 \n(Q) a = [1,2,3,4]; b = [2,4,6,8], d = 4 \n(R) a = [1,2,3,4]; b = [10,20,30,40], d = 4 \n(S) a = [1,2,3,4]; b = [1.1,2.1,3.1,4.1], d = 4     \n(A) \nP, Q, R, S \n(B) \nQ, R, S only \n(C) \nQ, R only \n(D) \nR, S only'),
#  Document(metadata={'producer': 'Microsoft: Print To PDF', 'creator': '', 'creationdate': '2023-11-08T15:43:22+05:30', 'source': '..\\data\\pdf\\2024 sample paper.pdf', 'file_path': '..\\data\\pdf\\2024 sample paper.pdf', 'total_pages': 29, 'format': 'PDF 1.7', 'title': 'Microsoft Word - DASampleQuestionPaperFinal', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2023-11-08T15:43:22+05:30', 'trapped': '', 'modDate': "D:20231108154322+05'30'", 'creationDate': "D:20231108154322+05'30'", 'page': 27}, page_content='GATE 2024 -- Data Science and Artificial Intelligence (DA) -- Sample Question Paper \nDA \n                                                                                                                    Page 28 of 29 \n \nQ.52 \nConsider the following undirected graph on 5 nodes \n \n \n \nAssume you are performing breadth first search on this graph using a queue \ndata structure. How many unique breadth first orderings are possible?\n(A) \n9 \n(B) \n24 \n(C) \n48 \n(D) \n120 \n \n \nQ.53 \n Let S2 be the variance of a random sample of size 𝑛 > 1 from a normal \npopulation with an unknown mean 𝜇 and an unknown finite variance 𝜎2. \nConsider the following statements: \n  (I) S2 is an unbiased estimator of 𝜎2, and 𝑆 is an unbiased estimator of 𝜎.  \n(II) (n-1/n) S2 is a maximum likelihood estimator of 𝜎2, andට𝑛−1\n𝑛 𝑆 is a \nmaximum likelihood estimator of 𝜎. Which of the above statements is true?  \n(A) \n(I) only  \n(B) \n(II) only \n(C) \nBoth (I) and (II)  \n(D) \nNeither (I) nor (II)'),
#  Document(metadata={'producer': 'Microsoft: Print To PDF', 'creator': '', 'creationdate': '2023-11-08T15:43:22+05:30', 'source': '..\\data\\pdf\\2024 sample paper.pdf', 'file_path': '..\\data\\pdf\\2024 sample paper.pdf', 'total_pages': 29, 'format': 'PDF 1.7', 'title': 'Microsoft Word - DASampleQuestionPaperFinal', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2023-11-08T15:43:22+05:30', 'trapped': '', 'modDate': "D:20231108154322+05'30'", 'creationDate': "D:20231108154322+05'30'", 'page': 28}, page_content='GATE 2024 -- Data Science and Artificial Intelligence (DA) -- Sample Question Paper \nDA \n                                                                                                                    Page 29 of 29 \n \nQ.54 \n The value of the real variable x ≥ 0, which maximizes the function \n 𝑓(𝑥) = 𝑥\u0bd8𝑒ି௫ is_____. (rounded off to two decimal places) \n \n \nQ.55 \nConsider the following relational schema:  \nemployee(empId,empName,empDept)  \ncustomer(custId,custName,salesRepId,rating)  \nsalesRepId is a foreign key referring to empId of the employee relation. \nAssume that each employee makes a sale to at least one customer. What does \nthe following query return?  \nSELECT empName  \nFROM employee E  \nWHERE NOT EXISTS (SELECT custId  \n               FROM customer C  \n               WHERE C.salesRepId = E.empId  \n               AND C.rating <> ’GOOD’);  \n(A) \nNames of all the employees with at least one of their customers having a \n‘GOOD’ rating. \n(B) \nNames of all the employees with at most one of their customers having a \n‘GOOD’ rating. \n(C) \nNames of all the employees with none of their customers having a ‘GOOD’ \nrating. \n(D) \nNames of all the employees with all their customers having a ‘GOOD’ rating. \n \nEND OF THE QUESTION PAPER')]

# %%
type(pdf_documents[0])
# Out:
# langchain_core.documents.base.Document
